# %% [markdown]
# <a href="https://colab.research.google.com/github/jwjung3030/pyfolio/blob/main/pyfolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 성과지표 확인(pyfolio)
# https://pypi.org/project/pyfolio/

# %%
pip -q install finance-datareader

# %%
pip -q install git+https://github.com/quantopian/pyfolio
# Out:
#      |████████████████████████████████| 52 kB 1.2 MB/s
# ...

# %%
import FinanceDataReader as fdr
import pyfolio as pf

df = fdr.DataReader('US500')
return_series = df['Close'].pct_change().fillna(0)

pf.create_returns_tear_sheet(return_series)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2006-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-15</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>189</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>8.292%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>251.12%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>19.954%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.50</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.15</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.82</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-56.775%</td>
#     </tr>
#     <tr>
# ...
